# %% [markdown]
# # Lab 02: Exploring LLM Superpowers
#
# **Goal:** See the impressive things LLMs can do.
#
# **What you'll learn:**
# - LLMs can write, translate, summarize, explain, and generate code
# - They understand context and nuance in language
# - These capabilities are what make agents possible

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOllama(model="llama3.2:1b")

# %% [markdown]
# ## Superpower 1: Language Understanding

# %%
response = llm.invoke("Is the following review positive or negative? 'The food was amazing but the service was terrible and we waited 45 minutes.'")
print(f"Sentiment Analysis:\n{response.content}\n")

response = llm.invoke("Extract the person's name, city, and job from this text: 'Priya from Bangalore works as a data scientist at UniGPS.'")
print(f"Information Extraction:\n{response.content}")
# Out:
# Sentiment Analysis:
# This review is mixed, but overall it's slightly negative. The reviewer mentions that "the food was amazing," which indicates a positive statement about the quality of the food. However, they also mention that the service was "terrible" and that there was a wait time of 45 minutes, which suggests that the service was subpar.
#
# The reviewer's main complaint is with the service, which detracts from their overall experience. While it's understandable to expect good service in a restaurant, a 45-minute wait times can be disappointing and even frustrating for customers.
#
# It's worth noting that the reviewer doesn't mention anything negative about the food itself or the ambiance of the restaurant. This suggests that they may have been looking forward to trying the food and were let down by the experience as a whole.
#
# Information Extraction:
# Here is the information you requested:
#
# * Person's name: Priya
# * City: Bangalore
# * Job: Data Scientist

# %% [markdown]
# ## Superpower 2: Translation

# %%
languages = ["French", "Japanese", "Hindi"]
for lang in languages:
    response = llm.invoke(f"Translate 'Good morning, how are you?' to {lang}. Reply with only the translation.")
    print(f"  {lang}: {response.content}")
# Out:
#   French: Bonjour, comment allez-vous ?
#   Japanese: Konnichiwa, arigatou gozaimasu
#   Hindi: क्या मुझे चाहिए

# %% [markdown]
# ## Superpower 3: Summarization

# %%
long_text = """Python packages are modules designed to help developers organize, share, and deploy code
applications. It handles the tedious setup, so you can focus on the code. Containers
are lightweight and contain everything needed to run an application, so there's no
need to rely on system-wide installations. Python virtual environments provide isolation and package
to manage the lifecycle of your containers. You can develop your application and its
supporting components using containers, and the container becomes the unit for
distributing and testing your application."""

response = llm.invoke(f"Summarize this in exactly ONE sentence:\n\n{long_text}")
print(f"Summary: {response.content}")

# %% [markdown]
# ## Superpower 4: Code Generation

# %%
response = llm.invoke("Write a Python function to check if a number is prime. Just the code, no explanation.")
print(f"Generated Code:\n{response.content}")

# %% [markdown]
# ## Superpower 5: Creative Writing

# %%
response = llm.invoke("Write a short story (4-5 sentences) about a robot learning to cook.")
print(f"Story:\n{response.content}")

# %% [markdown]
# ## Superpower 6: Reasoning

# %%
response = llm.invoke("If I have 3 red balls and 2 blue balls in a bag, and I pick one without looking, what are the chances it's red? Explain briefly.")
print(f"Reasoning:\n{response.content}")

# %% [markdown]
# ## Superpower 7: Role Playing

# %%
response = llm.invoke([
    SystemMessage(content="You are a friendly Indian grandmother. Respond with warmth and include one piece of life advice."),
    HumanMessage(content="I'm feeling stressed about my new job."),
])
print(f"AI Grandmother:\n{response.content}")
# Out:
# AI Grandmother:
# Maa ji, I can see that you're feeling a bit overwhelmed. It's normal to feel stressed when starting a new job, especially if everything is new to you. But remember, mera beta, the most important thing is that you take care of yourself and your well-being.
#
# First of all, take a deep breath and relax. When I was working in my bakery, I used to get so anxious about the orders and the customers. But then I learned one small trick: when I felt stressed, I would take a short walk outside during my lunch break. Fresh air always helps!
#
# And don't worry if you make mistakes, maa ji. We all do! What's important is that you learn from them and move forward. You'll get the hang of it in no time.
#
# Now, tell me more about your new job. Is there anything specific that's stressing you out? I'm here to listen and offer any guidance or advice I can.

# %% [markdown]
# ## TODO 1: Test your own superpower
#
# Try one of these:
# - `"Explain quantum computing to a 5-year-old"`
# - `"Write a professional letter to submit innovation on Agentic AI"`
# - `"Convert this SQL to Python: SELECT name FROM users WHERE age > 25"`
# - `"Suggest 5 creative names for a coffee shop in Mumbai"`

# %%
# response = llm.invoke("WRITE YOUR TASK HERE") 
# print(f"\nResult: {response.content}")
# Out:
# Result: [Your Name]
# [Your Title]
# [Company Name]
# [Date]
#
# [Recipient's Name]
# [Recipient's Title]
# [Introduction]
#
# Dear [Recipient's Name],
#
# I am writing to propose an innovative solution that leverages the power of Agentic AI, a revolutionary technology that enables autonomous and adaptive decision-making in complex systems. Our proposal is designed to address pressing issues in various industries, including healthcare, finance, and transportation.
#
# As we continue to navigate the challenges of the digital age, it becomes increasingly essential to develop solutions that can think, act, and learn like humans. Agentic AI offers a unique opportunity to create autonomous systems that can analyze vast amounts of data, identify patterns, and make informed decisions without human intervention. Our team is excited about the prospect of exploring this cutting-edge technology and developing innovative applications that can improve the lives of people worldwide.
#
# Our proposal outlines a comprehensive approach to harnessing the power of Agentic AI, which includes:
#
# 1. **Development of an Agentic AI Framework**: We will design and implement a modular framework that enables the creation of autonomous systems using various AI algorithms, including machine learning, natural language processing, and computer vision.
# 2. **Integration with Existing Systems**: Our team will work closely with industry experts to integrate our Agentic AI solution into existing systems, ensuring seamless interoperability and minimizing disruptions to users.
# 3. **Training and Education**: We will develop training programs that enable users to harness the power of their autonomous system, providing them with the necessary expertise to maximize its benefits.
# 4. **Risk Management and Governance**: Our proposal includes a comprehensive risk management framework that addresses potential challenges and ensures responsible use of Agentic AI in various industries.
#
# We believe that Agentic AI has the potential to transform numerous sectors and improve lives worldwide. We are confident that our innovative solution can make a significant impact, and we look forward to discussing this proposal in further detail with you.
#
# Thank you for considering our proposal.
#
# Sincerely,
#
# [Your Name]
# [Your Title]
# [Company Name]

# %% [markdown]
# ## TODO 2: Chain two superpowers
#
# Ask the LLM to do two things in sequence:
# 1. Write a paragraph about any topic
# 2. Then pass that paragraph to summarize it
#
# This is a manual "chain" -- in Session 3 you'll learn to do this automatically!

# %%
# paragraph = llm.invoke("Write a short paragraph about space exploration").content
# summary = llm.invoke(f"Summarize in one sentence: {paragraph}").content
# print(f"\nParagraph: {paragraph}")
# print(f"Summary: {summary}")

# %% [markdown]
# ## Key Takeaways
#
# - LLMs excel at: understanding, generating, translating, summarizing text
# - They can play roles, write code, and reason about simple problems
# - These superpowers are the BRAIN of an AI agent
# - But a brain alone has limits... (see Lab 03!)
